# %%
"""
Zadanie z szukaniem skarbu.
Mamy planszę 10 x 10.
Losujemy współrzędne x oraz y dla gracza i dla skarbu.
Celem gracza jest dotarcie do współrzędnych wylosowanego skarbu.

Podpowiedzi:
- wylosuj współrzędne x oraz y gracza i skarbu za pomocą funkcji z modułu random
- skorzystaj z pętli while
- steruj położeniem gracza za pomocą przycisków w, a, s, d - skorzystaj z funkcji input
- znajdź sposób na zmierzenie, czy gracz zbilża się, czy oddala się od skarbu i wyświetlaj podpowiedzi
- przerwij pętlę kiedy gracz wypadnie poza planszę
- przerwij pętlę (break) kiedy współrzędne gracza i skarbu będą równe

"""

import random

# losujemy x gracza
x_gracza = random.randint(1, 10)

# losujemy y gracza
y_gracza = random.randint(1, 10)

# analogicznie losujemy współrzędne dla skarbu
x_skarbu = random.randint(1, 10)
y_skarbu = random.randint(1, 10)


# definiujemy licznik
liczba_ruchow = 0

while True:
    odleglosc_przed = abs(x_skarbu - x_gracza) + abs(y_skarbu - y_gracza)
    print(f"Jesteś na polu x = {x_gracza}, y = {y_gracza}")
    ruch = input("""Wpisz:
    a - żeby wykonać ruch w lewo
    d - żeby wykonać ruch w prawo
    w - żedy wykonać ruch w góre
    s - żeby wykonać ruch w dół
    : """)
    if ruch =="a":
        x_gracza -= 1
    elif ruch =="d":
        x_gracza += 1
    elif ruch == "w":
        y_gracza += 1
    elif ruch == "s":
        y_gracza -= 1
    else:
        print("Błędna komenda. Czytaj uważniej!")
        continue
    odleglosc_po = abs(x_skarbu - x_gracza) + abs(y_skarbu - y_gracza)
    
    ###################
    # za pomocą instrukcji if sprawdź, czy współrzędne gracza i skarbu są równe
    # porównaj odległość przed wykonaniem ruchu i po wykonaniu ruchu
    # i wypisz czy zbliżamy się do skarbu, czy się od niego oddalamy
    # Jeżeli wypadniemy poza planszę - x_gracza lub y_gracza poza zakresem (1, 10)
    # wypisz komunikat o wypadnięciu z planszy i przerwij pętlę
